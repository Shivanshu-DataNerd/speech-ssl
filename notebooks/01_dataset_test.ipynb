# %%
import os, sys
PROJECT_ROOT = os.path.abspath("..")
sys.path.insert(0, PROJECT_ROOT)

# %%
from src.dataset import CommonVoiceSSLDataset


dataset = CommonVoiceSSLDataset("../data/raw/commonvoice_en_au")

print("Total files:", len(dataset))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.dataset import RawAudioDataset
#       3 dataset = RawAudioDataset("../data/raw/commonvoice_en_au")
#       5 print("Total files:", len(dataset))
#
# ImportError: cannot import name 'RawAudioDataset' from 'src.dataset' (c:\Users\intel\OneDrive\Desktop\PhD preparation\speech-ssl\src\dataset.py)

# %%
wave = dataset[0]
print(wave.shape)
print(wave.dtype)

# %%
torch.Size([samples])

# %%
from src.plot_utils import save_plot
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,4))
plt.plot(wave.numpy())
plt.title("Waveform Example")

save_plot(fig, "waveform_example.png")
print("Saved waveform plot as 'waveform_example.png'")
