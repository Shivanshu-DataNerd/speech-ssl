# %%
import os, sys
PROJECT_ROOT = os.path.abspath("..")
sys.path.insert(0, PROJECT_ROOT)

# %%
from src.dataset import RawAudioDataset

dataset = RawAudioDataset("../data/raw/commonvoice_en_au")

print("Total files:", len(dataset))

# %%
wave = dataset[0]
wave.shape

# %%
torch.Size([samples])

# %%
from src.plot_utils import save_plot
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,4))
plt.plot(wave.numpy())
plt.title("Waveform Example")

save_plot(fig, "waveform_example.png")
print("Saved waveform plot as 'waveform_example.png'")
